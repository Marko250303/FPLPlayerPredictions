# %%
import pandas as pd
import numpy as np
import matplotlib as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# **UČITAVANJE I PRIPREMA SKUPOVA PODATAKA**

# %%
filenames=["Abdoulaye_Doucoure",
           "Alejandro_Garnacho",
           "Alex_Iwobi",
           "Alexis_MacAllister",
           "Amadou_Onana",
           "Andreas_Pereira",
           "Anthony_Elanga",
           "Anthony_Gordon",
           "Bernardo_Silva",
           "Billy_Gilmour",
           "Boubacar_Kamara",
           "Brennan_Johnson",
           "Bruno_Fernandes",
           "Bruno_Guimaraes",
           "Bryan_Mbeumo",
           "Bukayo_Saka",
           "Callum_Hudson",
           "Carlos_Casimiro",
           "Christian_Norgaard",
           "Cole_Palmer",
           "Conor_Gallagher",
           "Danilo_Oliveira",
           "Declan_Rice",
           "Dejan_Kulusevski",
           "Dominik_Szoboszlai",
           "Douglas_Luiz",
           "Dwight_McNeil",
           "Eberechi_Eze",
           "Edson_Alvarez",
           "Enzo_Fernandez",
           "Gabriel_Martinelli",
           "Harry_Wilson",
           "Hwang_Hee",
           "Idrissa_Gueye",
           "James_Garner",
           "James_Maddison",
           "James_McAtee",
           "Jarrod_Bowen",
           "Jefferson_Lerma",
           "Joao_Gomes",
           "Joao_Palhinha",
           "John_McGinn",
           "Jordan_Ayew",
           "Josh_Brownhill",
           "Josh_Cullen",
           "Justin_Kluivert",
           "Kai_Havertz",
           "Kobbie_Mainoo",
           "Leandro_Trossard",
           "Leon_Bailey",
           "Lewis_Cook",
           "Lucas_Lima",
           "Luis_Diaz",
           "Marcus_Rashford",
           "Marcus_Tavernier",
           "Mario_Lemina",
           "Martin_Odegaard",
           "Mateo_Kovacic",
           "Mathias_Jensen",
           "Miguel_Almiron",
           "Mohamed_Salah",
           "Moises_Caicedo",
           "Morgan_Gibbs",
           "Mousa_Diaby",
           "Mykhailo_Mudryk",
           "Orel_Mangala",
           "Pablo_Sarabia",
           "Pape_Sarr",
           "Pascal_Gros",
           "Pedro_Neto",
           "Phil_Foden",
           "Raheem_Sterling",
           "Rodrigo_Hernandez",
           "Ross_Barkley",
           "Ryan_Christie",
           "Ryan_Yates",
           "Sander_Berge",
           "Scott_McTominay",
           "Sean_Longstaff",
           "Simon_Adingra",
           "Son_Heung",
           "Tahith_Chong",
           "Tomas_Soucek",
           "Vini_Souza",
           "Vitaly_Janelt",
           "Will_Hughes",
           "Willian_Borges",
           "Youri_Tielemans",
           "Yves_Bissouma"]

dfs={}

# %%
for dataframe in filenames:
    df=pd.read_csv(dataframe+".csv")
    
    dfs[dataframe.split('.')[0]]=df

# %%
df_Doucoure=dfs['Abdoulaye_Doucoure']
df_Garnacho=dfs['Alejandro_Garnacho']
df_Iwobi=dfs['Alex_Iwobi']
df_MacAllister=dfs['Alexis_MacAllister']
df_Onana=dfs['Amadou_Onana']
df_Pereira=dfs['Andreas_Pereira']
df_Elanga=dfs['Anthony_Elanga']
df_Gordon=dfs['Anthony_Gordon']
df_Silva=dfs['Bernardo_Silva']
df_Gilmour=dfs['Billy_Gilmour']
df_Kamara=dfs['Boubacar_Kamara']
df_Johnson=dfs['Brennan_Johnson']
df_Fernandes=dfs['Bruno_Fernandes']
df_Guimaraes=dfs['Bruno_Guimaraes']
df_Mbeumo=dfs['Bryan_Mbeumo']
df__Saka=dfs['Bukayo_Saka']
df_Hudson=dfs['Callum_Hudson']
df_Casimiro=dfs['Carlos_Casimiro']
df_Norgaard=dfs['Christian_Norgaard']
df_Palmer=dfs['Cole_Palmer']
df_Gallagher=dfs['Conor_Gallagher']
df_Oliveira=dfs['Danilo_Oliveira']
df_Rice=dfs['Declan_Rice']
df_Kulusevski=dfs['Dejan_Kulusevski']
df_Szoboszlai=dfs['Dominik_Szoboszlai']
df_Luiz=dfs['Douglas_Luiz']
df_McNeil=dfs['Dwight_McNeil']
df_Eze=dfs['Eberechi_Eze']
df_Alvarez=dfs['Edson_Alvarez']
df_Fernandez=dfs['Enzo_Fernandez']
df_Martinelli=dfs['Gabriel_Martinelli']
df_Wilson=dfs['Harry_Wilson']
df_Hee=dfs['Hwang_Hee']
df_Gueye=dfs['Idrissa_Gueye']
df_Garner=dfs['James_Garner']
df_Maddison=dfs['James_Maddison']
df_McAtee=dfs['James_McAtee']
df_Bowen=dfs['Jarrod_Bowen']
df_Lerma=dfs['Jefferson_Lerma']
df_Gomes=dfs['Joao_Gomes']
df_Palhinha=dfs['Joao_Palhinha']
df_McGinn=dfs['John_McGinn']
df_Ayew=dfs['Jordan_Ayew']
df_Brownhill=dfs['Josh_Brownhill']
df_Cullen=dfs['Josh_Cullen']
df_Kluivert=dfs['Justin_Kluivert']
df_Havertz=dfs['Kai_Havertz']
df_Mainoo=dfs['Kobbie_Mainoo']
df_Trossard=dfs['Leandro_Trossard']
df_Bailey=dfs['Leon_Bailey']
df_Cook=dfs['Lewis_Cook']
df_Lima=dfs['Lucas_Lima']
df_Diaz=dfs['Luis_Diaz']
df_Rashford=dfs['Marcus_Rashford']
df_Tavernier=dfs['Marcus_Tavernier']
df_Lemina=dfs['Mario_Lemina']
df_Odegaard=dfs['Martin_Odegaard']
df_Kovacic=dfs['Mateo_Kovacic']
df_Jensen=dfs['Mathias_Jensen']
df_Almiron=dfs['Miguel_Almiron']
df_Salah=dfs['Mohamed_Salah']
df_Caicedo=dfs['Moises_Caicedo']
df_Gibbs=dfs['Morgan_Gibbs']
df_Diaby=dfs['Mousa_Diaby']
df_Mudryk=dfs['Mykhailo_Mudryk']
df_Mangala=dfs['Orel_Mangala']
df_Sarabia=dfs['Pablo_Sarabia']
df_Sarr=dfs['Pape_Sarr']
df_Gros=dfs['Pascal_Gros']
df_Neto=dfs['Pedro_Neto']
df_Foden=dfs['Phil_Foden']
df_Sterling=dfs['Raheem_Sterling']
df_Hernandez=dfs['Rodrigo_Hernandez']
df_Barkley=dfs['Ross_Barkley']
df_Christie=dfs['Ryan_Christie']
df_Yates=dfs['Ryan_Yates']
df_Berge=dfs['Sander_Berge']
df_McTominay=dfs['Scott_McTominay']
df_Longstaff=dfs['Sean_Longstaff']
df_Adingra=dfs['Simon_Adingra']
df_Heung=dfs['Son_Heung']
df_Chong=dfs['Tahith_Chong']
df_Soucek=dfs['Tomas_Soucek']
df_Souza=dfs['Vini_Souza']
df_Janelt=dfs['Vitaly_Janelt']
df_Hughes=dfs['Will_Hughes']
df_Borges=dfs['Willian_Borges']
df_Tielemans=dfs['Youri_Tielemans']
df_Bissouma=dfs['Yves_Bissouma']

# %%
dataframes=[df_Doucoure,
            df_Garnacho,
            df_Iwobi,
            df_MacAllister,
            df_Onana,
            df_Pereira,
            df_Elanga,
            df_Gordon,
            df_Silva,
            df_Gilmour,
            df_Kamara,
            df_Johnson,
            df_Fernandes,
            df_Guimaraes,
            df_Mbeumo,
            df_Saka,
            df_Hudson,
            df_Casimiro,
            df_Norgaard,
            df_Palmer,
            df_Gallagher,
            df_Oliveira,
            df_Rice,
            df_Kulusevski,
            df_Szoboszlai,
            df_Luiz,
            df_McNeil,
            df_Eze,
            df_Alvarez,
            df_Fernandez,
            df_Martinelli,
            df_Wilson,
            df_Hee,
            df_Gueye,
            df_Garner,
            df_Maddison,
            df_McAtee,
            df_Bowen,
            df_Lerma,
            df_Gomes,
            df_Palhinha,
            df_McGinn,
            df_Ayew,
            df_Brownhill,
            df_Cullen,
            df_Kluivert,
            df_Havertz,
            df_Mainoo,
            df_Trossard,
            df_Bailey,
            df_Cook,
            df_Lima,
            df_Diaz,
            df_Rashford,
            df_Tavernier,
            df_Lemina,
            df_Odegaard,
            df_Kovacic,
            df_Jensen,
            df_Almiron,
            df_Salah,
            df_Caicedo,
            df_Gibbs,
            df_Diaby,
            df_Mudryk,
            df_Mangala,
            df_Sarabia,
            df_Sarr,
            df_Gros,
            df_Neto,
            df_Foden,
            df_Sterling,
            df_Hernandez,
            df_Barkley,
            df_Christie,
            df_Yates,
            df_Berge,
            df_McTominay,
            df_Longstaff,
            df_Adingra,
            df_Heung,
            df_Chong,
            df_Soucek,
            df_Souza,
            df_Janelt,
            df_Hughes,
            df_Borges,
            df_Tielemans,
            df_Bissouma]

# %%
df_Salah.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element  expected_assists  \
# 0        1      0   15             0        20.2      308              0.31
# 1        0      0   15             0        33.0      308              0.11
# 2        1      0   19             0        24.9      308              0.12
# 3        0      0   26             1        23.1      308              0.07
# 4        2      2   35             0        57.4      308              1.47
#
#    expected_goal_involvements  expected_goals  expected_goals_conceded  \
# 0                        0.59            0.28                     1.28
# 1                        1.34            1.23                     1.00
# 2                        0.30            0.18                     2.00
# 3                        0.87            0.80                     0.66
# 4                        1.71            0.24                     0.63
#
#    fixture  goals_conceded  goals_scored  ict_index  influence  \
# ...

# %%
def ubaci_ime_u_dataframe():
    for df,name in zip(dataframes,filenames):
        df["Firstname"]=name.split('_')[0]
        df["Lastname"]=name.split('_')[1]

# %%
def oblik():
    for df in dataframes:
        print(df.shape)

# %%
oblik()
# Out:
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 38)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)

# %%
ubaci_ime_u_dataframe()

# %%
df_Salah.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element  expected_assists  \
# 0        1      0   15             0        20.2      308              0.31
# 1        0      0   15             0        33.0      308              0.11
# 2        1      0   19             0        24.9      308              0.12
# 3        0      0   26             1        23.1      308              0.07
# 4        2      2   35             0        57.4      308              1.47
#
#    expected_goal_involvements  expected_goals  expected_goals_conceded  \
# 0                        0.59            0.28                     1.28
# 1                        1.34            1.23                     1.00
# 2                        0.30            0.18                     2.00
# 3                        0.87            0.80                     0.66
# 4                        1.71            0.24                     0.63
#
#    fixture  goals_conceded  goals_scored  ict_index  influence  \
# ...

# %%
oblik()
# Out:
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)

# %%
def izbaci_kolone(column_names):
    for dataframe in dataframes:
        dataframe.drop(columns=column_names,inplace=True)

# %%
column_names=['bps',
              'bonus',
              'selected',
              'starts',
              'creativity',
              'element',
              'ict_index',
              'influence',
              'kickoff_time',
              'round',
              'threat',
              'transfers_balance',
              'transfers_in',
              'transfers_out',
              'team_a_score',
              'team_h_score',
              'value',
              'fixture',
              'was_home',
              'expected_goal_involvements',
              'penalties_saved',
              'saves']

# %%
izbaci_kolone(column_names)

# %%
df_Salah.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.31            0.28
# 1        0             0              0.11            1.23
# 2        1             0              0.12            0.18
# 3        0             1              0.07            0.80
# 4        2             0              1.47            0.24
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.28               1             0       76
# 1                     1.00               1             1       85
# 2                     2.00               1             0       90
# 3                     0.66               0             1       90
# 4                     0.63               1             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0              7          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)

# %% [markdown]
# **DODATNO SREDJIVANJE I KREIRANJE NOVIH KOLONA**

# %% [markdown]
# **1.SPAJANJE SA TABELOM TIMOVA**

# %%
from IPython.display import HTML

# %%
def mapiranje_timova(df):
    df_teams=pd.read_csv("teams.csv")
    df_teams.head(20)
    
    team_names={
    1:"Arsenal",
    2:"Aston Vila",
    3:"Bournemouth",
    4:"Brentford",
    5:"Brighton",
    6:"Burnley",
    7:"Chelsea",
    8:"Crystal Palace",
    9:"Everton",
    10:"Fulham",
    11:"Liverpool",
    12:"Luton",
    13:"Man City",
    14:"Man Utd",
    15:"Newcastle",
    16:"Nott'm Forest",
    17:"Sheffield Utd",
    18:"Spurs",
    19:"West Ham",
    20:"Wolves",
    }
    
    df["Teams"]=df["opponent_team"].map(team_names)
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    mapiranje_timova(dataframe)

# %%
df_Salah.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.31            0.28
# 1        0             0              0.11            1.23
# 2        1             0              0.12            0.18
# 3        0             1              0.07            0.80
# 4        2             0              1.47            0.24
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.28               1             0       76
# 1                     1.00               1             1       85
# 2                     2.00               1             0       90
# 3                     0.66               0             1       90
# 4                     0.63               1             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0              7          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)

# %%
def ucitaj_tabelu():
    html="""
<iframe id="sofa-standings-embed-1-52186" src="https://widgets.sofascore.com/embed/tournament/1/season/52186/standings/Premier%20League?widgetTitle=Premier%20League&showCompetitionLogo=true" style=height:1112.5px!important;max-width:768px!important;width:100%!important; frameborder="0" scrolling="no"></iframe>
    <div style="font-size:12px;font-family:Arial,sans-serif;text-align:left">
      Standings provided by <a target="_blank" href="https://www.sofascore.com/">Sofascore</a>
    </div>
"""
    return(HTML(html))

# %%
ucitaj_tabelu()
# Out:
# <iframe id="sofa-standings-embed-1-52186" src="https://widgets.sofascore.com/embed/tournament/1/season/52186/standings/Premier%20League?widgetTitle=Premier%20League&showCompetitionLogo=true" style=height:1112.5px!important;max-width:768px!important;width:100%!important; frameborder="0" scrolling="no"></iframe>
#     <div style="font-size:12px;font-family:Arial,sans-serif;text-align:left">
#       Standings provided by <a target="_blank" href="https://www.sofascore.com/">Sofascore</a>
#     </div>

# %%
def mapiranje_tezine_protivnika(df):
    fixture_rating={
    "Arsenal":5,
    "Aston Vila":5,
    "Bournemouth":3,
    "Brentford":2,
    "Brighton":3,
    "Burnley":2,
    "Chelsea":4,
    "Crystal Palace":4,
    "Everton":3,
    "Fulham":3,
    "Liverpool":5,
    "Luton":2,
    "Man City":5,
    "Man Utd":4,
    "Newcastle":4,
    "Nott'm Forest":2,
    "Sheffield Utd":2,
    "Spurs":5,
    "West Ham":4,
    "Wolves":3,
    } 
    
    df["Fixture_Rating"]=df["Teams"].map(fixture_rating)
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    mapiranje_tezine_protivnika(dataframe)

# %%
df_Salah.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.31            0.28
# 1        0             0              0.11            1.23
# 2        1             0              0.12            0.18
# 3        0             1              0.07            0.80
# 4        2             0              1.47            0.24
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.28               1             0       76
# 1                     1.00               1             1       85
# 2                     2.00               1             0       90
# 3                     0.66               0             1       90
# 4                     0.63               1             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0              7          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)

# %%
new_column_names=["opponent_team","Teams"]

# %%
izbaci_kolone(new_column_names)

# %%
df_Salah.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.31            0.28
# 1        0             0              0.11            1.23
# 2        1             0              0.12            0.18
# 3        0             1              0.07            0.80
# 4        2             0              1.47            0.24
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  own_goals  \
# 0                     1.28               1             0       76          0
# 1                     1.00               1             1       85          0
# 2                     2.00               1             0       90          0
# 3                     0.66               0             1       90          0
# 4                     0.63               1             0       90          0
#
#    penalties_missed  red_cards  total_points  yellow_cards Firstname Lastname  \
# ...

# %%
oblik()
# Out:
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)

# %% [markdown]
# **2.DELTA KOLONE**

# %%
def izracunaj_delta_vrednosti(df):
    #GOLOVI
    
    delta_goals_scored=df.goals_scored-df.expected_goals
    
    #print(delta_goals_scored)
    
    df["Delta_Goals"]=delta_goals_scored
    
    #ASISTENCIJE
    
    delta_assists=df.assists-df.expected_assists
    
    #print(delta_assists)
    
    df["Delta_Assists"]=delta_assists
    
    #PRIMLJENI GOLOVI
    
    delta_goals_conceded=df.expected_goals_conceded-df.goals_conceded
    
    #print(delta_goals_conceded)
    
    df["Delta_Goals_Conceded"]=delta_goals_conceded
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    izracunaj_delta_vrednosti(dataframe)

# %%
df_Salah.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.31            0.28
# 1        0             0              0.11            1.23
# 2        1             0              0.12            0.18
# 3        0             1              0.07            0.80
# 4        2             0              1.47            0.24
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  own_goals  \
# 0                     1.28               1             0       76          0
# 1                     1.00               1             1       85          0
# 2                     2.00               1             0       90          0
# 3                     0.66               0             1       90          0
# 4                     0.63               1             0       90          0
#
#    penalties_missed  red_cards  total_points  yellow_cards Firstname Lastname  \
# ...

# %%
oblik()
# Out:
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)

# %% [markdown]
# **3.PROMENA REDOSLEDA I IMENA KOLONA**

# %%
def promeni_ime_kolona(df,column_names):
    df.rename(columns=column_names,inplace=True)

# %%
column_rename={'assists':'Assists',
              'clean_sheets':'Clean_Sheet',
              'expected_assists':'xA',
              'expected_goals':'xG',
              'expected_goals_conceded':'xGC',
              'goals_conceded':'Goals_Conceded',
              'goals_scored':'Goals_Scored',
              'minutes':'Minutes',
              'own_goals':'Own_Goals',
              'penalties_missed':'Penalites_Missed',
              'red_cards':'Red_Cards',
              'total_points':'Points',
              'yellow_cards':'Yellow_Cards'
             }

# %%
for dataframe in dataframes:
    promeni_ime_kolona(dataframe,column_rename)

# %%
df_Salah.head()
# Out:
#    Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0        1            0  0.31  0.28  1.28               1             0
# 1        0            0  0.11  1.23  1.00               1             1
# 2        1            0  0.12  0.18  2.00               1             0
# 3        0            1  0.07  0.80  0.66               0             1
# 4        2            0  1.47  0.24  0.63               1             0
#
#    Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# 0       76          0                 0          0       5             0
# 1       85          0                 1          0       5             0
# 2       90          0                 0          0       5             0
# 3       90          0                 0          0       8             0
# 4       90          0                 0          0      10             0
#
#   Firstname Lastname  Fixture_Rating  Delta_Goals  Delta_Assists  \
# ...

# %%
def promeni_redosled_kolona(new_column_order):
    for df in dataframes:
        df=df[new_column_order]

# %%
column_order=['Firstname',
              'Lastname',
              'Fixture_Rating',
              'Minutes',
              'Goals_Scored',
              'xG',
              'Delta_Goals',
              'Assists',
              'xA',
              'Delta_Assists',
              'Goals_Conceded',
              'xGC',
              'Delta_Goals_Conceded',
              'Clean_Sheet',
              'Own_Goals',
              'Penalites_Missed',
              'Yellow_Cards',
              'Red_Cards',
              'Points']

# %%
promeni_redosled_kolona(column_order)

# %%
def napravi_ciljni_atribut():
    for df in dataframes:
        df['Next_Points'] = df['Points'].shift(-1) #вредност поена играца у наредном колу и она се предвиђа
        
        for column in df.select_dtypes(include='number').columns:     
                df[f'Running_{column}'] = df[column].rolling(window=4, min_periods=1).mean() #просек тренутног и претходна 3 кола

# %%
napravi_ciljni_atribut()

# %%
df_Salah.head()
# Out:
#    Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0        1            0  0.31  0.28  1.28               1             0
# 1        0            0  0.11  1.23  1.00               1             1
# 2        1            0  0.12  0.18  2.00               1             0
# 3        0            1  0.07  0.80  0.66               0             1
# 4        2            0  1.47  0.24  0.63               1             0
#
#    Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# 0       76          0                 0          0       5             0
# 1       85          0                 1          0       5             0
# 2       90          0                 0          0       5             0
# 3       90          0                 0          0       8             0
# 4       90          0                 0          0      10             0
#
#   Firstname Lastname  Fixture_Rating  Delta_Goals  Delta_Assists  \
# ...

# %%
dataframes[0]
# Out:
#     Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0         0            0  0.10  0.56  1.50               1             0
# 1         0            0  0.03  0.09  3.11               4             0
# 2         0            0  0.10  0.21  1.16               1             0
# 3         0            0  0.03  1.07  1.24               2             1
# 4         0            0  0.00  0.00  1.02               1             0
# 5         0            0  0.05  0.12  1.04               1             1
# 6         1            0  0.20  0.37  0.89               2             0
# 7         0            1  0.22  1.14  0.72               0             1
# 8         0            0  0.00  0.00  2.24               2             0
# 9         0            1  0.01  0.19  0.66               0             0
# 10        0            0  0.01  0.10  0.53               1             0
# 11        1            0  0.02  0.74  2.24               2             1
# ...

# %%
oblik()
# Out:
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)

# %%
df_mid=pd.concat(dataframes)

# %%
df_mid
# Out:
#     Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0         0            0  0.10  0.56  1.50               1             0
# 1         0            0  0.03  0.09  3.11               4             0
# 2         0            0  0.10  0.21  1.16               1             0
# 3         0            0  0.03  1.07  1.24               2             1
# 4         0            0  0.00  0.00  1.02               1             0
# ..      ...          ...   ...   ...   ...             ...           ...
# 33        0            0  0.04  0.00  1.66               1             0
# 34        0            0  0.04  0.04  3.22               4             0
# 35        0            0  0.05  0.00  0.75               1             0
# 36        0            0  0.00  0.00  0.00               0             0
# 37        0            0  0.00  0.00  0.00               0             0
#
#     Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# ...

# %%
df_mid.shape
# Out:
# (3382, 38)

# %%
df_mid.to_csv("vezni.csv")
