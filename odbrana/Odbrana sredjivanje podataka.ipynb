# %%
import pandas as pd
import numpy as np
import matplotlib as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# **UČITAVANJE I PRIPREMA SKUPOVA PODATAKA**

# %%
filenames=["Aaron_Bissaka",
           "Adam_Smith",
           "Alfie_Doughty",
           "Amarii_Bell",
           "Andrew_Robertson",
           "Anel_Ahmedhodzic",
           "Antonee_Robinson",
           "Ashley_Young",
           "Auston_Trusty",
           "Axel_Disasi",
           "Benjamin_White",
           "Calvin_Bassey",
           "Charlie_Taylor",
           "Chris_Richards",
           "Craig_Dawson",
           "Cristian_Romero",
           "Dan_Burn",
           "Dara_OShea",
           "Destiny_Udogie",
           "Diego_Carlos",
           "Diogo_Dalot",
           "Emerson_Palmieri",
           "Ethan_Pinnock",
           "Ezri_Konsa",
           "Fabian_Schar",
           "Gabriel_Magalhaes",
           "Gabriel_Osho",
           "Harry_Maguire",
           "Ibrahima_Konate",
           "Igor_Julio",
           "Illia_Zabarnyi",
           "Issa_Kabore",
           "Jack_Robinson",
           "James_Tarkowski",
           "Jan_Hecke",
           "Jarrad_Branthwaite",
           "Jayden_Bogle",
           "Joachim_Andersen",
           "Joe_Gomez",
           "Joel_Veltman",
           "Joel_Ward",
           "Josko_Gvardiol",
           "Kieran_Trippier",
           "Kristoffer_Ajer",
           "Kurt_Zouma",
           "Kyle_Walker",
           "Levi_Colwill",
           "Lewis_Dunk",
           "Lloyd_Kelly",
           "Lucas_Digne",
           "Mads_Roerslev",
           "Malo_Gusto",
           "Manuel_Akanji",
           "Marc_Cucurella",
           "Marc_Guehi",
           "Marcos_Senesi",
           "Matty_Cash",
           "Max_Kilman",
           "Micky_Ven",
           "Milos_Kerkez",
           "Nathan_Ake",
           "Nathan_Collins",
           "Nayef_Aguerd",
           "Neco_Williams",
           "Nelson_Semedo",
           "Oleksandr_Zinchenko",
           "Olu_Aina",
           "Pau_Torres",
           "Pedro_Porro",
           "Rayan_Nouri",
           "Reece_Burke",
           "Ruben_Dias",
           "Thiago_Silva",
           "Tim_Ream",
           "Tosin_Adarabioyo",
           "Toti_Gomes",
           "Trent_Arnold",
           "Tyrick_Mitchell",
           "Victor_Silva",
           "Virgil_Dijk",
           "Vitalii_Mykolenko",
           "Vladimir_Coufal",
           "William_Saliba"]

dfs={}

# %%
for dataframe in filenames:
    df=pd.read_csv(dataframe+".csv")
    
    dfs[dataframe.split('.')[0]]=df

# %%
df_Bissaka=dfs['Aaron_Bissaka']
df_Smith=dfs['Adam_Smith']
df_Doughty=dfs['Alfie_Doughty']
df_Bell=dfs['Amarii_Bell']
df_Robertson=dfs['Andrew_Robertson']
df_Ahmedhodzic=dfs['Anel_Ahmedhodzic']
df_ARobinson=dfs['Antonee_Robinson']
df_Young=dfs['Ashley_Young']
df_Trusty=dfs['Auston_Trusty']
df_Disasi=dfs['Axel_Disasi']
df_White=dfs['Benjamin_White']
df_Bassey=dfs['Calvin_Bassey']
df_Taylor=dfs['Charlie_Taylor']
df_Richards=dfs['Chris_Richards']
df_Dawson=dfs['Craig_Dawson']
df_Romero=dfs['Cristian_Romero']
df_Burn=dfs['Dan_Burn']
df_OShea=dfs['Dara_OShea']
df_Udogie=dfs['Destiny_Udogie']
df_Carlos=dfs['Diego_Carlos']
df_Dalot=dfs['Diogo_Dalot']
df_Palmieri=dfs['Emerson_Palmieri']
df_Pinnock=dfs['Ethan_Pinnock']
df_Konsa=dfs['Ezri_Konsa']
df_Schar=dfs['Fabian_Schar']
df_Magalhaes=dfs['Gabriel_Magalhaes']
df_Osho=dfs['Gabriel_Osho']
df_Maguire=dfs['Harry_Maguire']
df_Konate=dfs['Ibrahima_Konate']
df_Julio=dfs['Igor_Julio']
df_Zabarnyi=dfs['Illia_Zabarnyi']
df_Kabore=dfs['Issa_Kabore']
df_Robinson=dfs['Jack_Robinson']
df_Tarkowski=dfs['James_Tarkowski']
df_Hecke=dfs['Jan_Hecke']
df_Branthwaite=dfs['Jarrad_Branthwaite']
df_Bogle=dfs['Jayden_Bogle']
df_Andersen=dfs['Joachim_Andersen']
df_Gomez=dfs['Joe_Gomez']
df_Veltman=dfs['Joel_Veltman']
df_Ward=dfs['Joel_Ward']
df_Gvardiol=dfs['Josko_Gvardiol']
df_Trippier=dfs['Kieran_Trippier']
df_Ajer=dfs['Kristoffer_Ajer']
df_Zouma=dfs['Kurt_Zouma']
df_Walker=dfs["Kyle_Walker"]
df_Colwill=dfs['Levi_Colwill']
df_Dunk=dfs['Lewis_Dunk']
df_Kelly=dfs['Lloyd_Kelly']
df_Digne=dfs['Lucas_Digne']
df_Roerslev=dfs['Mads_Roerslev']
df_Gusto=dfs['Malo_Gusto']
df_Akanji=dfs['Manuel_Akanji']
df_Cucurella=dfs['Marc_Cucurella']
df_Guehi=dfs['Marc_Guehi']
df_Senesi=dfs['Marcos_Senesi']
df_Cash=dfs['Matty_Cash']
df_Kilman=dfs['Max_Kilman']
df_Ven=dfs['Micky_Ven']
df_Kerkez=dfs['Milos_Kerkez']
df_Ake=dfs['Nathan_Ake']
df_Collins=dfs['Nathan_Collins']
df_Aguerd=dfs['Nayef_Aguerd']
df_Williams=dfs['Neco_Williams']
df_Semedo=dfs['Nelson_Semedo']
df_Zinchenko=dfs['Oleksandr_Zinchenko']
df_Aina=dfs['Olu_Aina']
df_Torres=dfs['Pau_Torres']
df_Porro=dfs['Pedro_Porro']
df_Nouri=dfs['Rayan_Nouri']
df_Burke=dfs['Reece_Burke']
df_Dias=dfs['Ruben_Dias']
df_TSilva=dfs['Thiago_Silva']
df_Ream=dfs['Tim_Ream']
df_Adarabioyo=dfs['Tosin_Adarabioyo']
df_Gomes=dfs['Toti_Gomes']
df_Arnold=dfs['Trent_Arnold']
df_Mitchell=dfs['Tyrick_Mitchell']
df_Silva=dfs['Victor_Silva']
df_Dijk=dfs['Virgil_Dijk']
df_Mykolenko=dfs['Vitalii_Mykolenko']
df_Coufal=dfs['Vladimir_Coufal']
df_Saliba=dfs['William_Saliba']

# %%
dataframes=[df_Bissaka,
            df_Smith,
            df_Doughty,
            df_Bell,
            df_Robertson,
            df_Ahmedhodzic,
            df_ARobinson,
            df_Young,
            df_Trusty,
            df_Disasi,
            df_White,
            df_Bassey,
            df_Taylor,
            df_Richards,
            df_Dawson,
            df_Romero,
            df_Burn,
            df_OShea,
            df_Udogie,
            df_Carlos,
            df_Dalot,
            df_Palmieri,
            df_Pinnock,
            df_Konsa,
            df_Schar,
            df_Magalhaes,
            df_Osho,
            df_Maguire,
            df_Konate,
            df_Julio,
            df_Zabarnyi,
            df_Kabore,
            df_Robinson,
            df_Tarkowski,
            df_Hecke,
            df_Branthwaite,
            df_Bogle,
            df_Andersen,
            df_Gomez,
            df_Veltman,
            df_Ward,
            df_Gvardiol,
            df_Trippier,
            df_Ajer,
            df_Zouma,
            df_Walker,
            df_Colwill,
            df_Dunk,
            df_Kelly,
            df_Digne,
            df_Roerslev,
            df_Gusto,
            df_Akanji,
            df_Cucurella,
            df_Guehi,
            df_Senesi,
            df_Cash,
            df_Kilman,
            df_Ven,
            df_Kerkez,
            df_Ake,
            df_Collins,
            df_Aguerd,
            df_Williams,
            df_Semedo,
            df_Zinchenko,
            df_Aina,
            df_Torres,
            df_Porro,
            df_Nouri,
            df_Burke,
            df_Dias,
            df_TSilva,
            df_Ream,
            df_Adarabioyo,
            df_Gomes,
            df_Arnold,
            df_Mitchell,
            df_Silva,
            df_Dijk,
            df_Mykolenko,
            df_Coufal,
            df_Saliba]

# %%
df_Saliba.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element  expected_assists  \
# 0        1      0   22             0        13.6       20              0.03
# 1        0      2   29             1         1.2       20              0.01
# 2        0      0   14             0        14.5       20              0.03
# 3        0      0   17             0         2.3       20              0.01
# 4        0      0   27             1         1.2       20              0.01
#
#    expected_goal_involvements  expected_goals  expected_goals_conceded  \
# 0                        0.03            0.00                     1.18
# 1                        0.01            0.00                     1.06
# 2                        0.07            0.04                     0.53
# 3                        0.01            0.00                     0.96
# 4                        0.01            0.00                     0.30
#
#    fixture  goals_conceded  goals_scored  ict_index  influence  \
# ...

# %%
def ubaci_ime_u_dataframe():
    for df,name in zip(dataframes,filenames):
        df["Firstname"]=name.split('_')[0]
        df["Lastname"]=name.split('_')[1]

# %%
def oblik():
    for df in dataframes:
        print(df.shape)

# %%
oblik()
# Out:
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)
# (38, 36)

# %%
ubaci_ime_u_dataframe()

# %%
df_Saliba.head()
# Out:
#    assists  bonus  bps  clean_sheets  creativity  element  expected_assists  \
# 0        1      0   22             0        13.6       20              0.03
# 1        0      2   29             1         1.2       20              0.01
# 2        0      0   14             0        14.5       20              0.03
# 3        0      0   17             0         2.3       20              0.01
# 4        0      0   27             1         1.2       20              0.01
#
#    expected_goal_involvements  expected_goals  expected_goals_conceded  \
# 0                        0.03            0.00                     1.18
# 1                        0.01            0.00                     1.06
# 2                        0.07            0.04                     0.53
# 3                        0.01            0.00                     0.96
# 4                        0.01            0.00                     0.30
#
#    fixture  goals_conceded  goals_scored  ict_index  influence  \
# ...

# %%
oblik()
# Out:
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)

# %%
def izbaci_kolone(column_names):
    for dataframe in dataframes:
        dataframe.drop(columns=column_names,inplace=True)

# %%
column_names=['bps',
              'bonus',
              'selected',
              'starts',
              'creativity',
              'element',
              'ict_index',
              'influence',
              'kickoff_time',
              'round',
              'threat',
              'transfers_balance',
              'transfers_in',
              'transfers_out',
              'team_a_score',
              'team_h_score',
              'value',
              'fixture',
              'was_home',
              'expected_goal_involvements',
              'penalties_saved',
              'saves']

# %%
izbaci_kolone(column_names)

# %%
df_Saliba.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.03            0.00
# 1        0             1              0.01            0.00
# 2        0             0              0.03            0.04
# 3        0             0              0.01            0.00
# 4        0             1              0.01            0.00
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.18               1             0       90
# 1                     1.06               0             0       90
# 2                     0.53               2             0       90
# 3                     0.96               1             0       90
# 4                     0.30               0             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0             16          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)

# %% [markdown]
# **DODATNO SREDJIVANJE I KREIRANJE NOVIH KOLONA**

# %% [markdown]
# **1.SPAJANJE SA TABELOM TIMOVA**

# %%
from IPython.display import HTML

# %%
def mapiranje_timova(df):
    df_teams=pd.read_csv("teams.csv")
    df_teams.head(20)
    
    team_names={
    1:"Arsenal",
    2:"Aston Vila",
    3:"Bournemouth",
    4:"Brentford",
    5:"Brighton",
    6:"Burnley",
    7:"Chelsea",
    8:"Crystal Palace",
    9:"Everton",
    10:"Fulham",
    11:"Liverpool",
    12:"Luton",
    13:"Man City",
    14:"Man Utd",
    15:"Newcastle",
    16:"Nott'm Forest",
    17:"Sheffield Utd",
    18:"Spurs",
    19:"West Ham",
    20:"Wolves",
    }
    
    df["Teams"]=df["opponent_team"].map(team_names)
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    mapiranje_timova(dataframe)

# %%
df_Saliba.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.03            0.00
# 1        0             1              0.01            0.00
# 2        0             0              0.03            0.04
# 3        0             0              0.01            0.00
# 4        0             1              0.01            0.00
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.18               1             0       90
# 1                     1.06               0             0       90
# 2                     0.53               2             0       90
# 3                     0.96               1             0       90
# 4                     0.30               0             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0             16          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)
# (38, 17)

# %%
def ucitaj_tabelu():
    html="""
<iframe id="sofa-standings-embed-1-52186" src="https://widgets.sofascore.com/embed/tournament/1/season/52186/standings/Premier%20League?widgetTitle=Premier%20League&showCompetitionLogo=true" style=height:1112.5px!important;max-width:768px!important;width:100%!important; frameborder="0" scrolling="no"></iframe>
    <div style="font-size:12px;font-family:Arial,sans-serif;text-align:left">
      Standings provided by <a target="_blank" href="https://www.sofascore.com/">Sofascore</a>
    </div>
"""
    return(HTML(html))

# %%
ucitaj_tabelu()
# Out:
# <iframe id="sofa-standings-embed-1-52186" src="https://widgets.sofascore.com/embed/tournament/1/season/52186/standings/Premier%20League?widgetTitle=Premier%20League&showCompetitionLogo=true" style=height:1112.5px!important;max-width:768px!important;width:100%!important; frameborder="0" scrolling="no"></iframe>
#     <div style="font-size:12px;font-family:Arial,sans-serif;text-align:left">
#       Standings provided by <a target="_blank" href="https://www.sofascore.com/">Sofascore</a>
#     </div>

# %%
def mapiranje_tezine_protivnika(df):
    fixture_rating={
    "Arsenal":5,
    "Aston Vila":5,
    "Bournemouth":3,
    "Brentford":2,
    "Brighton":3,
    "Burnley":2,
    "Chelsea":4,
    "Crystal Palace":4,
    "Everton":3,
    "Fulham":3,
    "Liverpool":5,
    "Luton":2,
    "Man City":5,
    "Man Utd":4,
    "Newcastle":4,
    "Nott'm Forest":2,
    "Sheffield Utd":2,
    "Spurs":5,
    "West Ham":4,
    "Wolves":3,
    } 
    
    df["Fixture_Rating"]=df["Teams"].map(fixture_rating)
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    mapiranje_tezine_protivnika(dataframe)

# %%
df_Saliba.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.03            0.00
# 1        0             1              0.01            0.00
# 2        0             0              0.03            0.04
# 3        0             0              0.01            0.00
# 4        0             1              0.01            0.00
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  \
# 0                     1.18               1             0       90
# 1                     1.06               0             0       90
# 2                     0.53               2             0       90
# 3                     0.96               1             0       90
# 4                     0.30               0             0       90
#
#    opponent_team  own_goals  penalties_missed  red_cards  total_points  \
# 0             16          0                 0          0             5
# ...

# %%
oblik()
# Out:
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)
# (38, 18)

# %%
new_column_names=["opponent_team","Teams"]

# %%
izbaci_kolone(new_column_names)

# %%
df_Saliba.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.03            0.00
# 1        0             1              0.01            0.00
# 2        0             0              0.03            0.04
# 3        0             0              0.01            0.00
# 4        0             1              0.01            0.00
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  own_goals  \
# 0                     1.18               1             0       90          0
# 1                     1.06               0             0       90          0
# 2                     0.53               2             0       90          0
# 3                     0.96               1             0       90          0
# 4                     0.30               0             0       90          0
#
#    penalties_missed  red_cards  total_points  yellow_cards Firstname Lastname  \
# ...

# %%
oblik()
# Out:
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)
# (38, 16)

# %% [markdown]
# **2.DELTA KOLONE**

# %%
def izracunaj_delta_vrednosti(df):
    #GOLOVI
    
    delta_goals_scored=df.goals_scored-df.expected_goals
    
    #print(delta_goals_scored)
    
    df["Delta_Goals"]=delta_goals_scored
    
    #ASISTENCIJE
    
    delta_assists=df.assists-df.expected_assists
    
    #print(delta_assists)
    
    df["Delta_Assists"]=delta_assists
    
    #PRIMLJENI GOLOVI
    
    delta_goals_conceded=df.expected_goals_conceded-df.goals_conceded
    
    #print(delta_goals_conceded)
    
    df["Delta_Goals_Conceded"]=delta_goals_conceded
    
    return(df.head(10))

# %%
for dataframe in dataframes:
    izracunaj_delta_vrednosti(dataframe)

# %%
df_Saliba.head()
# Out:
#    assists  clean_sheets  expected_assists  expected_goals  \
# 0        1             0              0.03            0.00
# 1        0             1              0.01            0.00
# 2        0             0              0.03            0.04
# 3        0             0              0.01            0.00
# 4        0             1              0.01            0.00
#
#    expected_goals_conceded  goals_conceded  goals_scored  minutes  own_goals  \
# 0                     1.18               1             0       90          0
# 1                     1.06               0             0       90          0
# 2                     0.53               2             0       90          0
# 3                     0.96               1             0       90          0
# 4                     0.30               0             0       90          0
#
#    penalties_missed  red_cards  total_points  yellow_cards Firstname Lastname  \
# ...

# %%
oblik()
# Out:
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)
# (38, 19)

# %% [markdown]
# **3.PROMENA REDOSLEDA I IMENA KOLONA**

# %%
def promeni_ime_kolona(df,column_names):
    df.rename(columns=column_names,inplace=True)

# %%
column_rename={'assists':'Assists',
              'clean_sheets':'Clean_Sheet',
              'expected_assists':'xA',
              'expected_goals':'xG',
              'expected_goals_conceded':'xGC',
              'goals_conceded':'Goals_Conceded',
              'goals_scored':'Goals_Scored',
              'minutes':'Minutes',
              'own_goals':'Own_Goals',
              'penalties_missed':'Penalites_Missed',
              'red_cards':'Red_Cards',
              'total_points':'Points',
              'yellow_cards':'Yellow_Cards'
             }

# %%
for dataframe in dataframes:
    promeni_ime_kolona(dataframe,column_rename)

# %%
df_Saliba.head()
# Out:
#    Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0        1            0  0.03  0.00  1.18               1             0
# 1        0            1  0.01  0.00  1.06               0             0
# 2        0            0  0.03  0.04  0.53               2             0
# 3        0            0  0.01  0.00  0.96               1             0
# 4        0            1  0.01  0.00  0.30               0             0
#
#    Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# 0       90          0                 0          0       5             0
# 1       90          0                 0          0       8             0
# 2       90          0                 0          0       1             0
# 3       90          0                 0          0       2             0
# 4       90          0                 0          0       6             0
#
#   Firstname Lastname  Fixture_Rating  Delta_Goals  Delta_Assists  \
# ...

# %%
def promeni_redosled_kolona(new_column_order):
    for df in dataframes:
        df=df[new_column_order]

# %%
column_order=['Firstname',
              'Lastname',
              'Fixture_Rating',
              'Minutes',
              'Goals_Scored',
              'xG',
              'Delta_Goals',
              'Assists',
              'xA',
              'Delta_Assists',
              'Goals_Conceded',
              'xGC',
              'Delta_Goals_Conceded',
              'Clean_Sheet',
              'Own_Goals',
              'Penalites_Missed',
              'Yellow_Cards',
              'Red_Cards',
              'Points']

# %%
promeni_redosled_kolona(column_order)

# %%
def napravi_ciljni_atribut():
    for df in dataframes:
        df['Next_Points'] = df['Points'].shift(-1) #вредност поена играца у наредном колу и она се предвиђа
        
        for column in df.select_dtypes(include='number').columns:     
                df[f'Running_{column}'] = df[column].rolling(window=4, min_periods=1).mean() #просек тренутног и претходна 3 кола

# %%
napravi_ciljni_atribut()

# %%
df_Saliba.head()
# Out:
#    Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0        1            0  0.03  0.00  1.18               1             0
# 1        0            1  0.01  0.00  1.06               0             0
# 2        0            0  0.03  0.04  0.53               2             0
# 3        0            0  0.01  0.00  0.96               1             0
# 4        0            1  0.01  0.00  0.30               0             0
#
#    Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# 0       90          0                 0          0       5             0
# 1       90          0                 0          0       8             0
# 2       90          0                 0          0       1             0
# 3       90          0                 0          0       2             0
# 4       90          0                 0          0       6             0
#
#   Firstname Lastname  Fixture_Rating  Delta_Goals  Delta_Assists  \
# ...

# %%
dataframes[0]
# Out:
#     Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0         1            1  0.78  0.00  2.27               0             0
# 1         0            0  0.10  0.00  1.25               1             0
# 2         0            0  0.04  0.00  1.24               2             0
# 3         0            0  0.01  0.00  2.27               3             0
# 4         0            0  0.00  0.00  0.74               0             0
# 5         0            0  0.00  0.00  0.00               0             0
# 6         0            0  0.00  0.00  0.00               0             0
# 7         0            0  0.00  0.00  0.00               0             0
# 8         0            0  0.00  0.00  0.00               0             0
# 9         0            0  0.00  0.00  0.00               0             0
# 10        0            1  0.01  0.00  1.01               0             0
# 11        0            0  0.00  0.00  0.00               0             0
# ...

# %%
oblik()
# Out:
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)
# (38, 38)

# %%
df_def=pd.concat(dataframes)

# %%
df_def
# Out:
#     Assists  Clean_Sheet    xA    xG   xGC  Goals_Conceded  Goals_Scored  \
# 0         1            1  0.78  0.00  2.27               0             0
# 1         0            0  0.10  0.00  1.25               1             0
# 2         0            0  0.04  0.00  1.24               2             0
# 3         0            0  0.01  0.00  2.27               3             0
# 4         0            0  0.00  0.00  0.74               0             0
# ..      ...          ...   ...   ...   ...             ...           ...
# 33        0            1  0.00  0.00  1.61               0             0
# 34        0            0  0.00  0.00  2.37               2             0
# 35        0            1  0.01  0.11  0.37               0             0
# 36        0            1  0.00  0.05  0.64               0             0
# 37        0            0  0.08  0.00  0.50               1             0
#
#     Minutes  Own_Goals  Penalites_Missed  Red_Cards  Points  Yellow_Cards  \
# ...

# %%
df_def.shape
# Out:
# (3154, 38)

# %%
df_def.to_csv("odbrana.csv")
